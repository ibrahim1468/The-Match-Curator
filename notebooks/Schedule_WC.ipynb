# %%
import pandas as pd

# %%
wc2026_schedule = [
    {"match_id": 1, "date": "2026-06-12", "home_team": "Mexico", "away_team": "South Africa", "group": "Group A", "stage": "group stage"},
    {"match_id": 2, "date": "2026-06-12", "home_team": "Korea Republic", "away_team": "Czechia", "group": "Group A", "stage": "group stage"},
    {"match_id": 3, "date": "2026-06-13", "home_team": "Canada", "away_team": "Bosnia and Herzegovina", "group": "Group B", "stage": "group stage"},
    {"match_id": 4, "date": "2026-06-13", "home_team": "USA", "away_team": "Paraguay", "group": "Group D", "stage": "group stage"},
    {"match_id": 5, "date": "2026-06-14", "home_team": "Qatar", "away_team": "Switzerland", "group": "Group B", "stage": "group stage"},
    {"match_id": 6, "date": "2026-06-14", "home_team": "Brazil", "away_team": "Morocco", "group": "Group C", "stage": "group stage"},
    {"match_id": 7, "date": "2026-06-14", "home_team": "Haiti", "away_team": "Scotland", "group": "Group C", "stage": "group stage"},
    {"match_id": 8, "date": "2026-06-14", "home_team": "Australia", "away_team": "Türkiye", "group": "Group D", "stage": "group stage"},
    {"match_id": 9, "date": "2026-06-14", "home_team": "Germany", "away_team": "Curaçao", "group": "Group E", "stage": "group stage"},
    {"match_id": 10, "date": "2026-06-15", "home_team": "Netherlands", "away_team": "Japan", "group": "Group F", "stage": "group stage"},
    {"match_id": 11, "date": "2026-06-15", "home_team": "Côte d'Ivoire", "away_team": "Ecuador", "group": "Group E", "stage": "group stage"},
    {"match_id": 12, "date": "2026-06-15", "home_team": "Sweden", "away_team": "Tunisia", "group": "Group F", "stage": "group stage"},
    {"match_id": 13, "date": "2026-06-15", "home_team": "Spain", "away_team": "Cabo Verde", "group": "Group H", "stage": "group stage"},
    {"match_id": 14, "date": "2026-06-16", "home_team": "Belgium", "away_team": "Egypt", "group": "Group G", "stage": "group stage"},
    {"match_id": 15, "date": "2026-06-16", "home_team": "Saudi Arabia", "away_team": "Uruguay", "group": "Group H", "stage": "group stage"},
    {"match_id": 16, "date": "2026-06-16", "home_team": "IR Iran", "away_team": "New Zealand", "group": "Group G", "stage": "group stage"},
    {"match_id": 17, "date": "2026-06-17", "home_team": "France", "away_team": "Senegal", "group": "Group I", "stage": "group stage"},
    {"match_id": 18, "date": "2026-06-17", "home_team": "Iraq", "away_team": "Norway", "group": "Group I", "stage": "group stage"},
    {"match_id": 19, "date": "2026-06-17", "home_team": "Argentina", "away_team": "Algeria", "group": "Group J", "stage": "group stage"},
    {"match_id": 20, "date": "2026-06-17", "home_team": "Austria", "away_team": "Jordan", "group": "Group J", "stage": "group stage"},
    {"match_id": 21, "date": "2026-06-17", "home_team": "Portugal", "away_team": "Congo DR", "group": "Group K", "stage": "group stage"},
    {"match_id": 22, "date": "2026-06-18", "home_team": "England", "away_team": "Croatia", "group": "Group L", "stage": "group stage"},
    {"match_id": 23, "date": "2026-06-18", "home_team": "Ghana", "away_team": "Panama", "group": "Group L", "stage": "group stage"},
    {"match_id": 24, "date": "2026-06-18", "home_team": "Uzbekistan", "away_team": "Colombia", "group": "Group K", "stage": "group stage"},
    {"match_id": 25, "date": "2026-06-18", "home_team": "Czechia", "away_team": "South Africa", "group": "Group A", "stage": "group stage"},
    {"match_id": 26, "date": "2026-06-19", "home_team": "Switzerland", "away_team": "Bosnia and Herzegovina", "group": "Group B", "stage": "group stage"},
    {"match_id": 27, "date": "2026-06-19", "home_team": "Canada", "away_team": "Qatar", "group": "Group B", "stage": "group stage"},
    {"match_id": 28, "date": "2026-06-19", "home_team": "Mexico", "away_team": "Korea Republic", "group": "Group A", "stage": "group stage"},
    {"match_id": 29, "date": "2026-06-20", "home_team": "USA", "away_team": "Australia", "group": "Group D", "stage": "group stage"},
    {"match_id": 30, "date": "2026-06-20", "home_team": "Scotland", "away_team": "Morocco", "group": "Group C", "stage": "group stage"},
    {"match_id": 31, "date": "2026-06-20", "home_team": "Brazil", "away_team": "Haiti", "group": "Group C", "stage": "group stage"},
    {"match_id": 32, "date": "2026-06-20", "home_team": "Türkiye", "away_team": "Paraguay", "group": "Group D", "stage": "group stage"},
    {"match_id": 33, "date": "2026-06-20", "home_team": "Netherlands", "away_team": "Sweden", "group": "Group F", "stage": "group stage"},
    {"match_id": 34, "date": "2026-06-21", "home_team": "Germany", "away_team": "Côte d'Ivoire", "group": "Group E", "stage": "group stage"},
    {"match_id": 35, "date": "2026-06-21", "home_team": "Ecuador", "away_team": "Curaçao", "group": "Group E", "stage": "group stage"},
    {"match_id": 36, "date": "2026-06-21", "home_team": "Tunisia", "away_team": "Japan", "group": "Group F", "stage": "group stage"},
    {"match_id": 37, "date": "2026-06-21", "home_team": "Spain", "away_team": "Saudi Arabia", "group": "Group H", "stage": "group stage"},
    {"match_id": 38, "date": "2026-06-22", "home_team": "Belgium", "away_team": "IR Iran", "group": "Group G", "stage": "group stage"},
    {"match_id": 39, "date": "2026-06-22", "home_team": "Uruguay", "away_team": "Cabo Verde", "group": "Group H", "stage": "group stage"},
    {"match_id": 40, "date": "2026-06-22", "home_team": "New Zealand", "away_team": "Egypt", "group": "Group G", "stage": "group stage"},
    {"match_id": 41, "date": "2026-06-22", "home_team": "Argentina", "away_team": "Austria", "group": "Group J", "stage": "group stage"},
    {"match_id": 42, "date": "2026-06-23", "home_team": "France", "away_team": "Iraq", "group": "Group I", "stage": "group stage"},
    {"match_id": 43, "date": "2026-06-23", "home_team": "Norway", "away_team": "Senegal", "group": "Group I", "stage": "group stage"},
    {"match_id": 44, "date": "2026-06-23", "home_team": "Jordan", "away_team": "Algeria", "group": "Group J", "stage": "group stage"},
    {"match_id": 45, "date": "2026-06-23", "home_team": "Portugal", "away_team": "Uzbekistan", "group": "Group K", "stage": "group stage"},
    {"match_id": 46, "date": "2026-06-24", "home_team": "England", "away_team": "Ghana", "group": "Group L", "stage": "group stage"},
    {"match_id": 47, "date": "2026-06-24", "home_team": "Panama", "away_team": "Croatia", "group": "Group L", "stage": "group stage"},
    {"match_id": 48, "date": "2026-06-24", "home_team": "Colombia", "away_team": "Congo DR", "group": "Group K", "stage": "group stage"},
    {"match_id": 49, "date": "2026-06-25", "home_team": "Switzerland", "away_team": "Canada", "group": "Group B", "stage": "group stage"},
    {"match_id": 50, "date": "2026-06-25", "home_team": "Bosnia and Herzegovina", "away_team": "Qatar", "group": "Group B", "stage": "group stage"},
    {"match_id": 51, "date": "2026-06-25", "home_team": "Scotland", "away_team": "Brazil", "group": "Group C", "stage": "group stage"},
    {"match_id": 52, "date": "2026-06-25", "home_team": "Morocco", "away_team": "Haiti", "group": "Group C", "stage": "group stage"},
    {"match_id": 53, "date": "2026-06-25", "home_team": "Czechia", "away_team": "Mexico", "group": "Group A", "stage": "group stage"},
    {"match_id": 54, "date": "2026-06-25", "home_team": "South Africa", "away_team": "Korea Republic", "group": "Group A", "stage": "group stage"},
    {"match_id": 55, "date": "2026-06-26", "home_team": "Curaçao", "away_team": "Côte d'Ivoire", "group": "Group E", "stage": "group stage"},
    {"match_id": 56, "date": "2026-06-26", "home_team": "Ecuador", "away_team": "Germany", "group": "Group E", "stage": "group stage"},
    {"match_id": 57, "date": "2026-06-26", "home_team": "Japan", "away_team": "Sweden", "group": "Group F", "stage": "group stage"},
    {"match_id": 58, "date": "2026-06-26", "home_team": "Tunisia", "away_team": "Netherlands", "group": "Group F", "stage": "group stage"},
    {"match_id": 59, "date": "2026-06-26", "home_team": "Türkiye", "away_team": "USA", "group": "Group D", "stage": "group stage"},
    {"match_id": 60, "date": "2026-06-26", "home_team": "Paraguay", "away_team": "Australia", "group": "Group D", "stage": "group stage"},
    {"match_id": 61, "date": "2026-06-27", "home_team": "Norway", "away_team": "France", "group": "Group I", "stage": "group stage"},
    {"match_id": 62, "date": "2026-06-27", "home_team": "Senegal", "away_team": "Iraq", "group": "Group I", "stage": "group stage"},
    {"match_id": 63, "date": "2026-06-27", "home_team": "Cabo Verde", "away_team": "Saudi Arabia", "group": "Group H", "stage": "group stage"},
    {"match_id": 64, "date": "2026-06-27", "home_team": "Uruguay", "away_team": "Spain", "group": "Group H", "stage": "group stage"},
    {"match_id": 65, "date": "2026-06-27", "home_team": "Egypt", "away_team": "IR Iran", "group": "Group G", "stage": "group stage"},
    {"match_id": 66, "date": "2026-06-27", "home_team": "New Zealand", "away_team": "Belgium", "group": "Group G", "stage": "group stage"},
    {"match_id": 67, "date": "2026-06-28", "home_team": "Panama", "away_team": "England", "group": "Group L", "stage": "group stage"},
    {"match_id": 68, "date": "2026-06-28", "home_team": "Croatia", "away_team": "Ghana", "group": "Group L", "stage": "group stage"},
    {"match_id": 69, "date": "2026-06-28", "home_team": "Colombia", "away_team": "Portugal", "group": "Group K", "stage": "group stage"},
    {"match_id": 70, "date": "2026-06-28", "home_team": "Congo DR", "away_team": "Uzbekistan", "group": "Group K", "stage": "group stage"},
    {"match_id": 71, "date": "2026-06-28", "home_team": "Algeria", "away_team": "Austria", "group": "Group J", "stage": "group stage"},
    {"match_id": 72, "date": "2026-06-28", "home_team": "Jordan", "away_team": "Argentina", "group": "Group J", "stage": "group stage"},

    # Round of 32
    {"match_id": 73, "date": "2026-06-29", "home_team": "2A", "away_team": "2B", "group": "", "stage": "Round of 32"},
    {"match_id": 74, "date": "2026-06-29", "home_team": "1C", "away_team": "2F", "group": "", "stage": "Round of 32"},
    {"match_id": 75, "date": "2026-06-30", "home_team": "1E", "away_team": "3ABCDF", "group": "", "stage": "Round of 32"},
    {"match_id": 76, "date": "2026-06-30", "home_team": "1F", "away_team": "2C", "group": "", "stage": "Round of 32"},
    {"match_id": 77, "date": "2026-06-30", "home_team": "2E", "away_team": "2I", "group": "", "stage": "Round of 32"},
    {"match_id": 78, "date": "2026-07-01", "home_team": "1I", "away_team": "3CDFGH", "group": "", "stage": "Round of 32"},
    {"match_id": 79, "date": "2026-07-01", "home_team": "1A", "away_team": "3CEFHI", "group": "", "stage": "Round of 32"},
    {"match_id": 80, "date": "2026-07-01", "home_team": "1L", "away_team": "3EHIJK", "group": "", "stage": "Round of 32"},
    {"match_id": 81, "date": "2026-07-02", "home_team": "1G", "away_team": "3AEHIJ", "group": "", "stage": "Round of 32"},
    {"match_id": 82, "date": "2026-07-02", "home_team": "1D", "away_team": "3BEFIJ", "group": "", "stage": "Round of 32"},
    {"match_id": 83, "date": "2026-07-03", "home_team": "1H", "away_team": "2J", "group": "", "stage": "Round of 32"},
    {"match_id": 84, "date": "2026-07-03", "home_team": "2K", "away_team": "2L", "group": "", "stage": "Round of 32"},
    {"match_id": 85, "date": "2026-07-03", "home_team": "1B", "away_team": "3EFGIJ", "group": "", "stage": "Round of 32"},
    {"match_id": 86, "date": "2026-07-03", "home_team": "2D", "away_team": "2G", "group": "", "stage": "Round of 32"},
    {"match_id": 87, "date": "2026-07-04", "home_team": "1J", "away_team": "2H", "group": "", "stage": "Round of 32"},
    {"match_id": 88, "date": "2026-07-04", "home_team": "1K", "away_team": "3DEIJL", "group": "", "stage": "Round of 32"},

    # Round of 16
    {"match_id": 89, "date": "2026-07-04", "home_team": "W73", "away_team": "W75", "group": "", "stage": "Round of 16"},
    {"match_id": 90, "date": "2026-07-05", "home_team": "W74", "away_team": "W77", "group": "", "stage": "Round of 16"},
    {"match_id": 91, "date": "2026-07-06", "home_team": "W76", "away_team": "W78", "group": "", "stage": "Round of 16"},
    {"match_id": 92, "date": "2026-07-06", "home_team": "W79", "away_team": "W80", "group": "", "stage": "Round of 16"},
    {"match_id": 93, "date": "2026-07-07", "home_team": "W83", "away_team": "W84", "group": "", "stage": "Round of 16"},
    {"match_id": 94, "date": "2026-07-07", "home_team": "W81", "away_team": "W82", "group": "", "stage": "Round of 16"},
    {"match_id": 95, "date": "2026-07-07", "home_team": "W86", "away_team": "W88", "group": "", "stage": "Round of 16"},
    {"match_id": 96, "date": "2026-07-08", "home_team": "W85", "away_team": "W87", "group": "", "stage": "Round of 16"},

    # Quarter-finals
    {"match_id": 97, "date": "2026-07-10", "home_team": "W89", "away_team": "W90", "group": "", "stage": "Quarter-final"},
    {"match_id": 98, "date": "2026-07-11", "home_team": "W93", "away_team": "W94", "group": "", "stage": "Quarter-final"},
    {"match_id": 99, "date": "2026-07-12", "home_team": "W91", "away_team": "W92", "group": "", "stage": "Quarter-final"},
    {"match_id": 100, "date": "2026-07-12", "home_team": "W95", "away_team": "W96", "group": "", "stage": "Quarter-final"},

    # Semi-finals
    {"match_id": 101, "date": "2026-07-15", "home_team": "W97", "away_team": "W98", "group": "", "stage": "Semi-final"},
    {"match_id": 102, "date": "2026-07-16", "home_team": "W99", "away_team": "W100", "group": "", "stage": "Semi-final"},

    # Third place play-off
    {"match_id": 103, "date": "2026-07-19", "home_team": "RU101", "away_team": "RU102", "group": "", "stage": "Play-off for third place"},

    # Final
    {"match_id": 104, "date": "2026-07-20", "home_team": "W101", "away_team": "W102", "group": "", "stage": "Final"},
]

df = pd.DataFrame(wc2026_schedule)

# %%
df.head()
# Out:
#    match_id        date       home_team               away_team    group  \
# 0         1  2026-06-12          Mexico            South Africa  Group A
# 1         2  2026-06-12  Korea Republic                 Czechia  Group A
# 2         3  2026-06-13          Canada  Bosnia and Herzegovina  Group B
# 3         4  2026-06-13             USA                Paraguay  Group D
# 4         5  2026-06-14           Qatar             Switzerland  Group B
#
#          stage
# 0  group stage
# 1  group stage
# 2  group stage
# 3  group stage
# 4  group stage

# %%
df["match"] = df["home_team"] + " vs " + df["away_team"]

# %%
df = df.drop(columns = ["home_team", "away_team"])

# %%
df[["team1", "team2"]] = df["match"].str.split(" vs ", expand = True)

# %%
knockout_stages = ["Round of 32", "Round of 16", "Quarter-final", "Semi-final", "Final", "Play-off for third place"]
mask = df["stage"].isin(knockout_stages)
df.loc[mask, ["match", "team1", "team2"]] = "TBD"

# %%
df.to_csv(r"FIFA_WC_2026.csv", index = False)
